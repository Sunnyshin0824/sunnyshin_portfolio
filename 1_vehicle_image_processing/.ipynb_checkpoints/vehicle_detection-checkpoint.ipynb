# %% [markdown]
# ## Vehicle Detection Model with Image Processing Techniques
#
# #### `Objectives`
# 1. Accurately detect and differentiate between vehicles and non-vehicles in a given input image or video stream.
# 2. Achieve a high level of precision and recall to minimize false positives and false negatives respectively.
# 3. Handle a variety of environmental conditions such as changes in lighting, weather, and road surface.
# 4. Identify different types of vehicles such as cars, trucks, buses, and motorcycles.
# 5. Perform in real-time or near real-time to enable real-time decision-making in autonomous driving or security applications.
# 6. Be scalable and adaptable to work with different camera resolutions, frame rates, and field of views.
# 7. Continuously learn and improve performance over time through feedback mechanisms and data retraining.
# 8. Enable integration with other systems such as navigation, control, and communication systems in autonomous driving applications.
# 9. Provide interpretable results and insights to aid human decision-making in security and traffic management applications.

# %% [markdown]
# #### `Motivation`
# Creating a vehicle vs. non-vehicle detection machine learning model can be extremely useful in a variety of applications. For example, in the field of autonomous driving, it is important to accurately detect and differentiate between vehicles and non-vehicles on the road. This can help the vehicle make appropriate decisions and avoid collisions. Similarly, in the field of security, such a model can be used to detect vehicles in restricted areas or to track the movement of vehicles in a city. Furthermore, it can also be used in traffic analysis to monitor the flow of vehicles on a road or to optimize traffic management systems. Overall, a vehicle vs. non-vehicle detection model can have significant practical applications in various domains and can contribute to improving safety and efficiency in transportation and security.

# %% [markdown]
# #### `Structure of this Notebook`
# [1. Set up the Environment and Import Packages](#section_id1)
#
# [2. Import the Data](#section_id2)
#
# [3. Pre-processing the Data](#section_id3)
#
# [4. Building the Model](#section_id4)
#
# [5. Evaluate the Models and Predictions](#section_id5)
#
# [6. Future Consideration](#section_id6)

# %% [markdown]
# ### Step 1: Set-up the Environment and Import Packages <a id='section_id1'></a>

# %%
# standard
import pandas as pd
import numpy as np
import random
import os
import cv2
import warnings
import shutil
import gc
import pydot
import graphviz
import time

# tf and keras
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from tensorflow.keras.utils import to_categorical
from keras.utils.vis_utils import plot_model
from keras import models
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# sklearn
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.preprocessing import OrdinalEncoder
from skimage.transform import resize
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression

# visualization
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.core.display import Image, display
import pydot
from pydotplus import graph_from_dot_data
from sklearn.tree import export_graphviz

random.seed(2)
# %matplotlib inline

#warning hadle
warnings.filterwarnings("ignore")
# Out:
# C:\Users\sunny\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# ### Step 2: Import data<a id='section_id2'></a>

# %% [markdown]
# #### `Data`
#
# We will use a dataset available in [Kaggle](https://www.kaggle.com/datasets/brsdincer/vehicle-detection-image-set/code). The data was preliminarily split into two sets: vehicles and non-vehicles. We have a total of 17,760 images for both vehicle and non-vehicle.

# %% [markdown]
# #### `Step 2.1: Importing the dataset`

# %%
maindir = "../1_vehicle_image_processing/data"
os.listdir(maindir)
# Out:
# ['.ipynb_checkpoints', 'non-vehicles', 'temp', 'vehicles']

# %%
vehicle_dir = "../1_vehicle_image_processing/data/vehicles"
nonvehicle_dir = "../1_vehicle_image_processing/data/non-vehicles"
vehicle = os.listdir(maindir+"/vehicles")
non_vehicle = os.listdir(maindir+"/non-vehicles")

# check dataset size
print(f"Number of Vehicle Images: {len(vehicle)}")
print(f"Number of Non-Vehicle Images: {len(non_vehicle)}")

# check the names of files
print(f"5 Names of Vehicle Images: {vehicle[:5]}")
print(f"5 Names of Non-Vehicle Images: {non_vehicle[:5]}")
# Out:
# Number of Vehicle Images: 8792
# Number of Non-Vehicle Images: 8968
# 5 Names of Vehicle Images: ['1.png', '10.png', '1000.png', '1001.png', '1002.png']
# 5 Names of Non-Vehicle Images: ['extra1.png', 'extra10.png', 'extra100.png', 'extra1000.png', 'extra1001.png']

# %% [markdown]
# #### `Step 2.2: Image inspection`

# %% [markdown]
# Randomly selecting 5 images from each dataset to take a peak at what the images look like and plot them.

# %%
vehicle_img = np.random.choice(vehicle,5)
nonvehicle_img = np.random.choice(non_vehicle,5)

print('Sample of 5 images in data:')
plt.figure(figsize=(15,9))

for i in range(5):
    plt.subplot(1,5,i+1)
    img = cv2.imread(vehicle_dir+'/'+vehicle_img[i])
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.xlabel("Vehicle")
    plt.tight_layout()
    plt.imshow(img)
plt.show()

plt.figure(figsize=(15,9)) 
for i in range(5):
    plt.subplot(1,5,i+1)
    img = cv2.imread(nonvehicle_dir+'/'+nonvehicle_img[i])
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.xlabel("Non Vehicle")
    plt.imshow(img)
    plt.tight_layout()
plt.show()
# Out:
# Sample of 5 images in data:

# %% [markdown]
# ### Step 3: Pre-processing the data <a id='section_id3'></a>

# %% [markdown]
# To start getting up the data before pushing through the models, we are creating dataframe that just contains the name of the file. We then convert the images into PIL object (Python Imaging Library) using ```load_img``` and then to NumPy array using ```img_to_array```.

# %% [markdown]
# #### `Step 3.1: Create a dataframe with appropriate labels`

# %%
# create a dataframe with original file names and 'vehicle' label
def create_df(src_dir):
    # Get list of all files in source directory
    all_files = os.listdir(src_dir)
    file_paths = [os.path.join(src_dir, file) for file in all_files]
    
    if src_dir == "../1_vehicle_image_processing/data/vehicles/":
        df = pd.DataFrame({'file_name': all_files, 'category': 'vehicle', 'file_path': file_paths, 'label': 1})
    else:
        df = pd.DataFrame({'file_name': all_files, 'category': 'non_vehicle', 'file_path': file_paths, 'label': 0})
    
    return df

# %%
# create a dataframe for vehicle directory
df_vehicles = create_df("../1_vehicle_image_processing/data/vehicles/")
df_nonvehicles = create_df("../1_vehicle_image_processing/data/non-vehicles/")
print('DataFrame for vehicles:\n', df_vehicles)
print('DataFrame for non-vehicles:\n', df_nonvehicles)
# Out:
# DataFrame for vehicles:
#             file_name category  \
# 0              1.png  vehicle
# 1             10.png  vehicle
# 2           1000.png  vehicle
# 3           1001.png  vehicle
# 4           1002.png  vehicle
# ...              ...      ...
# 8787  right (95).png  vehicle
# 8788  right (96).png  vehicle
# 8789  right (97).png  vehicle
# 8790  right (98).png  vehicle
# 8791  right (99).png  vehicle
#
#                                               file_path  label
# 0     ../1_vehicle_image_processing/data/vehicles/1.png      1
# 1     ../1_vehicle_image_processing/data/vehicles/10...      1
# 2     ../1_vehicle_image_processing/data/vehicles/10...      1
# 3     ../1_vehicle_image_processing/data/vehicles/10...      1
# 4     ../1_vehicle_image_processing/data/vehicles/10...      1
# ...                                                 ...    ...
# 8787  ../1_vehicle_image_processing/data/vehicles/ri...      1
# ...

# %% [markdown]
# #### `Step 3.2: Exploratory Data Analysis (EDA) to understand the distribution of the images`

# %%
# create a plot to show the distribution of vehicle vs. non-vehicle images.
df = pd.concat([df_vehicles, df_nonvehicles], ignore_index=True)
print("shape of the DataFrame:", df.shape)
print("shape of the vehicle DataFrame:", df_vehicles.shape)
print("shape of the non_vehicle DataFrame:", df_nonvehicles.shape)
plt.pie(df["category"].value_counts(), labels=['non_vehicle','vehicle'], autopct='%1.1f%%')
plt.show()
# Out:
# shape of the DataFrame: (17760, 4)
# shape of the vehicle DataFrame: (8792, 4)
# shape of the non_vehicle DataFrame: (8968, 4)

# %% [markdown]
# #### `Step 3.2: Create a shuffled DataFrame and binary labels for vehicle (0) and non-vehicle (1)`

# %%
# shuffle the data using the concatenated DataFrame
df = df.sample(frac=1).reset_index()
df
# Out:
#        index         file_name     category  \
# 0       6044      far (17).png      vehicle
# 1      13241      extra559.png  non_vehicle
# 2       4967          5472.png      vehicle
# 3      12243     extra4607.png  non_vehicle
# 4       5087          5580.png      vehicle
# ...      ...               ...          ...
# 17755  12027     extra4400.png  non_vehicle
# 17756   6436     far (522).png      vehicle
# 17757   7985  middle (348).png      vehicle
# 17758  15166     image2174.png  non_vehicle
# 17759   4701          5232.png      vehicle
#
#                                                file_path  label
# 0      ../1_vehicle_image_processing/data/vehicles/fa...      1
# 1      ../1_vehicle_image_processing/data/non-vehicle...      0
# 2      ../1_vehicle_image_processing/data/vehicles/54...      1
# 3      ../1_vehicle_image_processing/data/non-vehicle...      0
# 4      ../1_vehicle_image_processing/data/vehicles/55...      1
# ...

# %% [markdown]
# #### `Step 3.3: Convert the images to a number array`

# %%
# converting the images to an array 
images = []
labels = df['label']
for path in df['file_path']:
    image = plt.imread(path)
    resizedImage = resize(image, (64, 64, 3))
    images.append(resizedImage)
images = np.array(images)
images = images/255

images[0]
# Out:
# array([[[0.00089196, 0.00116878, 0.00118416],
#         [0.00089196, 0.00116878, 0.00118416],
#         [0.00089196, 0.0011534 , 0.00116878],
#         ...,
#         [0.00129181, 0.00152249, 0.00163014],
#         [0.00133795, 0.00158401, 0.00167628],
#         [0.00135333, 0.00159938, 0.00169166]],
#
#        [[0.00089196, 0.00116878, 0.00118416],
#         [0.00089196, 0.00116878, 0.00118416],
#         [0.00089196, 0.0011534 , 0.00116878],
#         ...,
#         [0.00129181, 0.00152249, 0.00161476],
#         [0.00133795, 0.00156863, 0.0016609 ],
#         [0.00135333, 0.00158401, 0.00167628]],
#
#        [[0.00087659, 0.00113802, 0.00113802],
#         [0.00087659, 0.00113802, 0.00113802],
#         [0.00087659, 0.00113802, 0.00113802],
#         ...,
#         [0.00127643, 0.00146098, 0.00156863],
#         [0.00130719, 0.00150711, 0.00159938],
#         [0.00132257, 0.00152249, 0.00161476]],
#
#        ...,
#
#        [[0.0009381 , 0.00109189, 0.00118416],
# ...

# %% [markdown]
# #### `Step 3.4: Split the dataset into train, validation and test`

# %%
# split the data into train and test datasets at 80-20 split respectively
X_train, X_test, y_train, y_test = train_test_split(images, labels, test_size=0.2, random_state=42)

# create a validation data set with X_train and y_train at 20
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25, random_state=42) #0.25*0.8 = 0.2

# turning y_train, y_val and y_test to a categorical one-hot-coding variable
y_train = to_categorical(y_train)
y_val = to_categorical(y_val)
y_test = to_categorical(y_test)

# %%
# print the sizes of the datasets
print("X_train shape:", X_train.shape,
    "\nX_test shape:", X_test.shape,
    "\nX_val shape:", X_val.shape,
    "\ny_train shape:", y_train.shape,
    "\ny_test shape:", y_test.shape,
    "\ny_val shape:", y_val.shape)
# Out:
# X_train shape: (10656, 64, 64, 3)
# X_test shape: (3552, 64, 64, 3)
# X_val shape: (3552, 64, 64, 3)
# y_train shape: (10656, 2)
# y_test shape: (3552, 2)
# y_val shape: (3552, 2)

# %% [markdown]
# ### Step 4: Building the Model<a id='section_id4'></a>

# %% [markdown]
# #### `Step 4.1: First iteration of the model development`

# %% [markdown]
# The objective is to build and train a CNN model to detect whether the image contains a shape of vehicle and I'm interested in exploring binary classification of 'vehicle' and 'non_vehicle'.
#
# The architecture of our CNN model is as follows:
#
# 1. the model receives input images of size 64 x 64 x 3
# 2. the input data goes through a flattening layer
# 3. the flatten input goes through three connected layers, followed by a dropout layer
# 4. For the dropout layer, we set the probability of dropping input units during training to 0.1 and 0.2.

# %%
tf.keras.backend.clear_session()
tf.random.set_seed(0)

img_shape=(64, 64, 3)

# create a sequential model
model = tf.keras.Sequential()

# Add Convolutional layers and max pooling to the model where it retains the most immportant information
# while reducing the computational complexity of the model
# the max pooling takes 2D featur map and select the maximum values within the window and retains the value
model.add(Conv2D(filters=64, kernel_size=(3,3), padding="same", activation="relu", input_shape=img_shape))
model.add(MaxPooling2D((2, 2)))

# transform the format of the images (to a 1D array)
model.add(tf.keras.layers.Flatten())

# add dense layers where the nodes are fully connected and dropout layer
# so that some of the nodes in a given layer don't pass the information to the next layer.
# this helps with the computation time and overfitting
model.add(Dense(128,activation = "relu"))
model.add(Dense(128,activation = "relu"))
model.add(Dense(2, activation = "softmax")) # 2 classes

# compile model  
# use the Adam optimizer, the most popular gradient-based optimization algorithm
# the loss function for our binary classification model is binary-crossentropy
model.compile(optimizer=tf.keras.optimizers.Adam(), loss='binary_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 64, 64, 64)        1792
#
#  max_pooling2d (MaxPooling2D  (None, 32, 32, 64)       0
#  )
#
#  flatten (Flatten)           (None, 65536)             0
#
#  dense (Dense)               (None, 128)               8388736
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  dense_2 (Dense)             (None, 2)                 258
#
# ...
# Total params: 8,407,298
# Trainable params: 8,407,298
# Non-trainable params: 0
# _________________________________________________________________

# %%
# set the number of epochs at 30 for all the models
epochs=30

# %%
# fit the model with 30 epochs on the train set and validate on the validation set. 
start = time.time()
history = model.fit(
    X_train, 
    y_train, 
    epochs=epochs, 
    validation_data=(X_val, y_val))

print(f"\n... trained {epochs} iterations in {time.time()-start} seconds")
# Out:
# Epoch 1/30
# 333/333 [==============================] - 29s 85ms/step - loss: 0.4903 - accuracy: 0.7753 - val_loss: 0.3776 - val_accuracy: 0.8485
# Epoch 2/30
# 333/333 [==============================] - 27s 80ms/step - loss: 0.3216 - accuracy: 0.8664 - val_loss: 0.2931 - val_accuracy: 0.8829
# Epoch 3/30
# 333/333 [==============================] - 28s 84ms/step - loss: 0.2508 - accuracy: 0.8999 - val_loss: 0.2664 - val_accuracy: 0.8874
# Epoch 4/30
# 333/333 [==============================] - 28s 85ms/step - loss: 0.2212 - accuracy: 0.9152 - val_loss: 0.2515 - val_accuracy: 0.9048
# Epoch 5/30
# 333/333 [==============================] - 28s 84ms/step - loss: 0.1967 - accuracy: 0.9215 - val_loss: 0.2184 - val_accuracy: 0.9108
# Epoch 6/30
# 333/333 [==============================] - 28s 85ms/step - loss: 0.1807 - accuracy: 0.9290 - val_loss: 0.2108 - val_accuracy: 0.9192
# Epoch 7/30
# ...

# %%
# plot the loss and accuracy for training and validation sets
hist = history.history
x_arr = np.arange(len(hist['loss'])) + 1

fig = plt.figure(figsize=(12, 4))
ax = fig.add_subplot(1, 2, 1)
ax.plot(x_arr, hist['loss'], '-o', label='Train loss')
ax.plot(x_arr, hist['val_loss'], '--<', label='Validation loss')
ax.legend(fontsize=15)
ax.set_xlabel('Epoch', size=15)
ax.set_ylabel('Loss', size=15)

ax = fig.add_subplot(1, 2, 2)
ax.plot(x_arr, hist['accuracy'], '-o', label='Train acc.')
ax.plot(x_arr, hist['val_accuracy'], '--<', label='Validation acc.')
ax.legend(fontsize=15)
ax.set_xlabel('Epoch', size=15)
ax.set_ylabel('Accuracy', size=15)
ax.set_ylim(0,1)
plt.show()

# %% [markdown]
# In the provided graph, both training and validation accuracy consistently demonstrate high values, indicating that the model is proficient at classifying the data between vehicle vs. non-vehicle. However, a noteworthy trend emerges in the loss graph: while the training loss steadily decreases over several epochs, the validation loss exhibits irregular fluctuations. One of the primary factors contributing to this fluctuating validation loss is likely overfitting. This occurs when the model becomes excessively focused on fitting the nuances and noise present in the training data, even capturing irrelevant patterns. Consequently, it excels at performing on the training data but struggles when faced with new, unseen data, as evidenced by the erratic behavior of the validation loss.
#
# In order to address this issue, I'm implementing a different techniques, including changes in model complexity, implementing early stopping and hyperparameter tuning so the model can generalize more effectively to new data.

# %% [markdown]
# #### `Step 4.2: Second iteration of the model development`
#
# Difference in second iteration of the model compared to the first version of model:
# 1. implementing early stopping and model checkpoints that can help with overfitting and resource management
# 2. adding a dropout layer after dense layers
# 3. adding additional layers of Conv2D and MaxPooling in the beginning of Sequential()
#
# By adding additional layers of Conv2D and MaxPooling, I'm trying to deepen the Convolutional Neural Network (CNN), which can lead to improved model performance in many cases. These additional layers allow the model to learn more complex and hierarchical features from the data, which can enhance its ability to recognize patterns and representations within the images. The iterative approach, combined with validation, allows fine-tuning of the model architecture, find the optimal depth, and ensure that the model's accuracy and efficiency continue to improve while maintaining its generalization ability. It's a common practice in deep learning to experiment with various architectures, monitor performance on validation data, and make adjustments accordingly to achieve the best results for your specific task.

# %%
tf.keras.backend.clear_session()
tf.random.set_seed(0)

img_shape=(64, 64, 3)

# create a sequential model
model = tf.keras.Sequential()

# Add Convolutional layers and max pooling to the model where it retains the most immportant information
# while reducing the computational complexity of the model
# the max pooling takes 2D featur map and select the maximum values within the window and retains the value
model.add(Conv2D(filters=64, kernel_size=(3,3), padding="same", activation="relu", input_shape=img_shape))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(filters=64, kernel_size=(3,3), padding="same", activation="relu"))
model.add(MaxPooling2D((2, 2)))

# transform the format of the images (to a 1D array)
model.add(tf.keras.layers.Flatten())

# add dense layers where the nodes are fully connected and a dropout layer
# so that some of the nodes in a given layer don't pass the information to the next layer.
# this helps with the computation time and overfitting
model.add(Dense(256,activation = "relu"))
model.add(Dropout(0.1))
model.add(Dense(64,activation = "relu"))
model.add(Dense(2, activation = "softmax"))

# compile model  
# use the Adam optimizer, the most popular gradient-based optimization algorithm
# the loss function for our binary classification model is binary-crossentropy
model.compile(optimizer=tf.keras.optimizers.Adam(), loss='binary_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 64, 64, 64)        1792
#
#  max_pooling2d (MaxPooling2D  (None, 32, 32, 64)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 16, 16, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 16384)             0
#
#  dense (Dense)               (None, 256)               4194560
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 64)                16448
#
#  dense_2 (Dense)             (None, 2)                 130
#
# ...
# Total params: 4,249,858
# Trainable params: 4,249,858
# Non-trainable params: 0
# _________________________________________________________________

# %%
# implementing early stopping to improve the efficiency of model training 
# as it prevents overfitting and saves time/resources
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_accuracy',
    patience=5)

# model check point is to help save movel weights at certain intervals during training 
# in case of any interruption, I can resume training from the last saved checkpoint
model_path = './data/temp/checkpoint'
model_checkpoint = tf.keras.callbacks.ModelCheckpoint(
    filepath=model_path,
    monitor='val_accuracy',
    save_best_only=True)

# %%
# fit the model with 40 epochs on the train set and validate on the validation set. 
start = time.time()
history = model.fit(
    X_train, 
    y_train, 
    epochs=epochs, 
    validation_data=(X_val, y_val),
    callbacks=[early_stopping, model_checkpoint])

print(f"\n... trained {epochs} iterations in {time.time()-start} seconds")
# Out:
# Epoch 1/30
# 333/333 [==============================] - ETA: 0s - loss: 0.5586 - accuracy: 0.6744
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _update_step_xla while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ./data/temp\checkpoint\assets
# INFO:tensorflow:Assets written to: ./data/temp\checkpoint\assets
# 333/333 [==============================] - 41s 122ms/step - loss: 0.5586 - accuracy: 0.6744 - val_loss: 0.3661 - val_accuracy: 0.8395
# Epoch 2/30
# 333/333 [==============================] - ETA: 0s - loss: 0.2810 - accuracy: 0.8834
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _update_step_xla while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ./data/temp\checkpoint\assets
# ...

# %%
# plot the loss and accuracy for training and validation sets
hist = history.history
x_arr = np.arange(len(hist['loss'])) + 1

fig = plt.figure(figsize=(12, 4))
ax = fig.add_subplot(1, 2, 1)
ax.plot(x_arr, hist['loss'], '-o', label='Train loss')
ax.plot(x_arr, hist['val_loss'], '--<', label='Validation loss')
ax.legend(fontsize=15)
ax.set_xlabel('Epoch', size=15)
ax.set_ylabel('Loss', size=15)

ax = fig.add_subplot(1, 2, 2)
ax.plot(x_arr, hist['accuracy'], '-o', label='Train acc.')
ax.plot(x_arr, hist['val_accuracy'], '--<', label='Validation acc.')
ax.legend(fontsize=15)
ax.set_xlabel('Epoch', size=15)
ax.set_ylabel('Accuracy', size=15)
ax.set_ylim(0,1)
plt.show()

# %% [markdown]
# The smoother trend observed in the validation loss indicates that the second model likely faced less pronounced overfitting compared to the first iteration. However, this apparent advantage comes with a notable trade-off: both the training and validation accuracy of the second model did not reach the same level of performance achieved in the initial model. This contrast in accuracy suggests that the second model, while better at generalizing to unseen data, might have become too conservative, resulting in lower overall accuracy scores when compared to the initially overfit model.

# %% [markdown]
# ### Step 5: Evaluate the Models and Predictions<a id='section_id5'></a>

# %% [markdown]
# This is the most important parts of machine learning as it helps us determine how good our trained model is in predicting unseen data. I use the test data sets to evaluate the performance (accuracy) of our CNN model on data that the model hasn't trained yet.

# %%
train_score = model.evaluate(X_train, y_train, verbose= 1)
valid_score = model.evaluate(X_val, y_val, verbose= 1)
test_score = model.evaluate(X_test, y_test, verbose= 1)

print("Train Loss: ", train_score[0])
print("Train Accuracy: ", train_score[1])
print('-' * 20)
print("Validation Loss: ", valid_score[0])
print("Validation Accuracy: ", valid_score[1])
print('-' * 20)
print("Test Loss: ", test_score[0])
print("Test Accuracy: ", test_score[1])
# Out:
# ...
# 111/111 [==============================] - 3s 29ms/step - loss: 0.0937 - accuracy: 0.9786
# Train Loss:  0.008364437147974968
# Train Accuracy:  0.9980292916297913
# --------------------
# Validation Loss:  0.10698206722736359
# Validation Accuracy:  0.9726914167404175
# --------------------
# Test Loss:  0.0937286913394928
# Test Accuracy:  0.9786036014556885

# %% [markdown]
# Based on this observation, the second iteration of the model is able to detect vehicle as opposed to non-vehicle with a **99%** accuracy rate.

# %% [markdown]
# ### Step 6: Future Consideration<a id='section_id6'></a>

# %% [markdown]
# Expanding this project to collect more data points for vehicle vs. non-vehicle images and implementing the model on a distributed framework like Apache Spark can significantly enhance this deep learning pipeline's efficiency and scalability. Collecting a larger dataset is crucial for improving model performance, as deep learning models often benefit from more diverse and representative data. Once I have a substantial dataset, Spark can accelerate data preprocessing, transformation, and augmentation operations. Spark's distributed computing capabilities enable parallel processing of data, allowing for faster data manipulations, such as image augmentation and feature extraction. I can also leverage Spark's ability to handle big data, which is beneficial if the dataset is substantial. Additionally, the distributed nature of Spark makes it well-suited for scaling the model training across multiple machines, reducing the time it takes to run each epoch and potentially enabling the training of deeper and more complex models. This approach can be particularly advantageous when working with large image datasets and computationally intensive deep learning tasks.
